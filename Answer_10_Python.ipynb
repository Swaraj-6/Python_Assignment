# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

def count_pos_tags(text):
    words = word_tokenize(text)

    tagged_words = pos_tag(words)

    counts = {
        'verb': 0,
        'noun': 0,
        'pronoun': 0,
        'adjective': 0
    }

    for word, tag in tagged_words:
        if tag.startswith('VB'):  
            counts['verb'] += 1
        elif tag.startswith('NN'):  
            counts['noun'] += 1
        elif tag.startswith('PRP'): 
            counts['pronoun'] += 1
        elif tag.startswith('JJ'):  
            counts['adjective'] += 1

    return counts
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
#  Example usage
text = "I love eating delicious food."
counts = count_pos_tags(text)
print(counts)
# Out:
# {'verb': 2, 'noun': 1, 'pronoun': 1, 'adjective': 1}

# %%
text = "The sun shines brightly on a clear summer day, casting long shadows on the green meadow."
counts = count_pos_tags(text)
print(counts)
# Out:
# {'verb': 1, 'noun': 6, 'pronoun': 0, 'adjective': 3}
